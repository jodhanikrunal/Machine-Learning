# %%
import cv2
from matplotlib.pyplot import subplots, imshow, show

def plot_image(data_generator):
    data_generator.fit(images)
    image_iterator = data_generator.flow(images)
    fig, rows = subplots(nrows=1,nclose=4,figsize=(18,18))
    for row in rows:
        row.imshow(image_iterator.next()[0].astype('uint8'))
        row.axis('off')

    show()

img = cv2.imread("E:/Machine-Learning/ML Club/volleyball_29.jpg")

images = img.reshape(-1,img.shape[0], img.shape[1], img.shape[2])

imshow(images[0])
